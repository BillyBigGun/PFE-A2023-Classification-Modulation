# %% [markdown]
# # Tuning

# %% [markdown]
# ## ANN

# %%
import sys
import matplotlib.pyplot as plt
sys.path.append("neural_network")
from hyperparameter_tuner import HyperparameterTuner

# %%
tuner = HyperparameterTuner()
tuner.tune_ann()
# Out:
# 2023-11-21 17:58:38,841	INFO worker.py:1673 -- Started a local Ray instance.
# 2023-11-21 17:58:40,172	INFO tune.py:220 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2023-11-21 17:58:40,175	INFO tune.py:586 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2023-11-21 17:58:40,179	INFO registry.py:107 -- Detected unknown callable for trainable. Converting to class.
# == Status ==
# Current time: 2023-11-21 17:58:40 (running for 00:00:00.31)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# Result logdir: /home/will/ray_results/train_ann_2023-11-21_17-58-40
# Number of trials: 16/30 (16 PENDING)
# +-----------------------+----------+-------+----------------------+-----------------+
# | Trial name            | status   | loc   | hidden_sizes         |   learning_rate |
# |-----------------------+----------+-------+----------------------+-----------------|
# | train_ann_82f07_00000 | PENDING  |       | [128, 64, 32, 1_4540 |          0.001  |
# | train_ann_82f07_00001 | PENDING  |       | [128, 64, 32, 1_f200 |          0.0001 |
# | train_ann_82f07_00002 | PENDING  |       | [128, 64, 32, 1_4cc0 |          1e-05  |
# | train_ann_82f07_00003 | PENDING  |       | [128, 64, 32, 1_f180 |          0.001  |
# | train_ann_82f07_00004 | PENDING  |       | [128, 64, 32, 1_5a80 |          0.0001 |
# | train_ann_82f07_00005 | PENDING  |       | [128, 64, 32, 1_df80 |          1e-05  |
# | train_ann_82f07_00006 | PENDING  |       | [128, 64, 32, 1_f980 |          0.001  |
# | train_ann_82f07_00007 | PENDING  |       | [128, 64, 32, 16]    |          0.0001 |
# | train_ann_82f07_00008 | PENDING  |       | [128, 64, 32, 16]    |          1e-05  |
# | train_ann_82f07_00009 | PENDING  |       | [128, 64, 32, 1_5140 |          0.001  |
# | train_ann_82f07_00010 | PENDING  |       | [128, 64, 32, 1_e940 |          0.0001 |
# | train_ann_82f07_00011 | PENDING  |       | [128, 64, 32, 1_6340 |          1e-05  |
# | train_ann_82f07_00012 | PENDING  |       | [128, 64, 32, 1_6940 |          0.001  |
# | train_ann_82f07_00013 | PENDING  |       | [128, 64, 32, 1_5400 |          0.0001 |
# | train_ann_82f07_00014 | PENDING  |       | [128, 64, 32, 1_f140 |          1e-05  |
# | train_ann_82f07_00015 | PENDING  |       | [128, 64, 32, 1_cb80 |          0.001  |
# +-----------------------+----------+-------+----------------------+-----------------+
#
#
# == Status ==
# Current time: 2023-11-21 17:58:45 (running for 00:00:05.37)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# Result logdir: /home/will/ray_results/train_ann_2023-11-21_17-58-40
# Number of trials: 16/30 (16 PENDING)
# +-----------------------+----------+-------+----------------------+-----------------+
# | Trial name            | status   | loc   | hidden_sizes         |   learning_rate |
# |-----------------------+----------+-------+----------------------+-----------------|
# | train_ann_82f07_00000 | PENDING  |       | [128, 64, 32, 1_4540 |          0.001  |
# | train_ann_82f07_00001 | PENDING  |       | [128, 64, 32, 1_f200 |          0.0001 |
# | train_ann_82f07_00002 | PENDING  |       | [128, 64, 32, 1_4cc0 |          1e-05  |
# | train_ann_82f07_00003 | PENDING  |       | [128, 64, 32, 1_f180 |          0.001  |
# | train_ann_82f07_00004 | PENDING  |       | [128, 64, 32, 1_5a80 |          0.0001 |
# | train_ann_82f07_00005 | PENDING  |       | [128, 64, 32, 1_df80 |          1e-05  |
# | train_ann_82f07_00006 | PENDING  |       | [128, 64, 32, 1_f980 |          0.001  |
# | train_ann_82f07_00007 | PENDING  |       | [128, 64, 32, 16]    |          0.0001 |
# | train_ann_82f07_00008 | PENDING  |       | [128, 64, 32, 16]    |          1e-05  |
# | train_ann_82f07_00009 | PENDING  |       | [128, 64, 32, 1_5140 |          0.001  |
# | train_ann_82f07_00010 | PENDING  |       | [128, 64, 32, 1_e940 |          0.0001 |
# | train_ann_82f07_00011 | PENDING  |       | [128, 64, 32, 1_6340 |          1e-05  |
# | train_ann_82f07_00012 | PENDING  |       | [128, 64, 32, 1_6940 |          0.001  |
# | train_ann_82f07_00013 | PENDING  |       | [128, 64, 32, 1_5400 |          0.0001 |
# | train_ann_82f07_00014 | PENDING  |       | [128, 64, 32, 1_f140 |          1e-05  |
# | train_ann_82f07_00015 | PENDING  |       | [128, 64, 32, 1_cb80 |          0.001  |
# +-----------------------+----------+-------+----------------------+-----------------+
# 2023-11-21 17:58:46,410	WARNING worker.py:2074 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,424	WARNING worker.py:2074 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: fffffffffffffffffddb05e46b8a6afd025b187d01000000 Worker ID: 4c74ea07115101371c25d7d0a8602cb33b6ecd4369a9899a42774fbf Node ID: 7294c89f93e58d3b267bcca152171df33f71123cc43ccc813a25f846 Worker IP address: 172.24.110.107 Worker port: 37045 Worker PID: 17986 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None. Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,441	ERROR tune_controller.py:1383 -- Trial task failed for trial train_ann_82f07_00003
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/worker.py", line 2565, in get
#     raise value
# ray.exceptions.RayActorError: The actor died unexpectedly before finishing this task.
# 	class_name: ImplicitFunc
# 	actor_id: fddb05e46b8a6afd025b187d01000000
# 	pid: 17986
# 	namespace: d1a5c8c1-75fe-4766-b0a6-d6ef88500cde
# 	ip: 172.24.110.107
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None. Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name           </th></tr>
# </thead>
# <tbody>
# <tr><td>train_ann_82f07_00000</td></tr>
# <tr><td>train_ann_82f07_00001</td></tr>
# <tr><td>train_ann_82f07_00002</td></tr>
# <tr><td>train_ann_82f07_00003</td></tr>
# <tr><td>train_ann_82f07_00004</td></tr>
# <tr><td>train_ann_82f07_00005</td></tr>
# <tr><td>train_ann_82f07_00006</td></tr>
# <tr><td>train_ann_82f07_00007</td></tr>
# <tr><td>train_ann_82f07_00008</td></tr>
# <tr><td>train_ann_82f07_00009</td></tr>
# <tr><td>train_ann_82f07_00010</td></tr>
# <tr><td>train_ann_82f07_00011</td></tr>
# <tr><td>train_ann_82f07_00012</td></tr>
# <tr><td>train_ann_82f07_00013</td></tr>
# <tr><td>train_ann_82f07_00014</td></tr>
# <tr><td>train_ann_82f07_00015</td></tr>
# <tr><td>train_ann_82f07_00016</td></tr>
# <tr><td>train_ann_82f07_00017</td></tr>
# <tr><td>train_ann_82f07_00018</td></tr>
# <tr><td>train_ann_82f07_00019</td></tr>
# <tr><td>train_ann_82f07_00020</td></tr>
# <tr><td>train_ann_82f07_00021</td></tr>
# <tr><td>train_ann_82f07_00022</td></tr>
# <tr><td>train_ann_82f07_00023</td></tr>
# <tr><td>train_ann_82f07_00024</td></tr>
# <tr><td>train_ann_82f07_00025</td></tr>
# <tr><td>train_ann_82f07_00026</td></tr>
# <tr><td>train_ann_82f07_00027</td></tr>
# <tr><td>train_ann_82f07_00028</td></tr>
# <tr><td>train_ann_82f07_00029</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2023-11-21 17:58:46,473	WARNING worker.py:2074 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,490	WARNING worker.py:2074 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffff8fd676a48849b9dbbf76917101000000 Worker ID: e510c234ef206177e6d72bf37153eb0aa274a5b095a5b95360d7e2a4 Node ID: 7294c89f93e58d3b267bcca152171df33f71123cc43ccc813a25f846 Worker IP address: 172.24.110.107 Worker port: 44479 Worker PID: 17985 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None. Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,495	WARNING worker.py:2074 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,503	WARNING worker.py:2074 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffff8b093a6416f01655613e9ae001000000 Worker ID: 90c2b886344fa66444fc7d0cda4249eea5bd8fb6a0f932c5099ffef8 Node ID: 7294c89f93e58d3b267bcca152171df33f71123cc43ccc813a25f846 Worker IP address: 172.24.110.107 Worker port: 39193 Worker PID: 17983 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None. Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,511	ERROR tune_controller.py:1383 -- Trial task failed for trial train_ann_82f07_00002
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/worker.py", line 2565, in get
#     raise value
# ray.exceptions.RayActorError: The actor died unexpectedly before finishing this task.
# 	class_name: ImplicitFunc
# 	actor_id: 8fd676a48849b9dbbf76917101000000
# 	pid: 17985
# 	namespace: d1a5c8c1-75fe-4766-b0a6-d6ef88500cde
# 	ip: 172.24.110.107
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None. Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,527	WARNING worker.py:2074 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,545	WARNING worker.py:2074 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffffbb198dccb8ecc03073098d2001000000 Worker ID: 209fdeefb428d409513e74677a3ca5d34fdf8b35224af912ad6e7a38 Node ID: 7294c89f93e58d3b267bcca152171df33f71123cc43ccc813a25f846 Worker IP address: 172.24.110.107 Worker port: 34479 Worker PID: 17984 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None. Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,563	ERROR tune_controller.py:1383 -- Trial task failed for trial train_ann_82f07_00001
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/worker.py", line 2565, in get
#     raise value
# ray.exceptions.RayActorError: The actor died unexpectedly before finishing this task.
# 	class_name: ImplicitFunc
# 	actor_id: bb198dccb8ecc03073098d2001000000
# 	pid: 17984
# 	namespace: d1a5c8c1-75fe-4766-b0a6-d6ef88500cde
# 	ip: 172.24.110.107
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None. Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# 2023-11-21 17:58:46,603	ERROR tune_controller.py:1383 -- Trial task failed for trial train_ann_82f07_00000
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/worker.py", line 2565, in get
#     raise value
# ray.exceptions.RayActorError: The actor died unexpectedly before finishing this task.
# 	class_name: ImplicitFunc
# 	actor_id: 8b093a6416f01655613e9ae001000000
# 	pid: 17983
# 	namespace: d1a5c8c1-75fe-4766-b0a6-d6ef88500cde
# 	ip: 172.24.110.107
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None. Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# == Status ==
# Current time: 2023-11-21 17:58:50 (running for 00:00:10.38)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# Result logdir: /home/will/ray_results/train_ann_2023-11-21_17-58-40
# Number of trials: 20/30 (4 ERROR, 16 PENDING)
# +-----------------------+----------+-------+----------------------+-----------------+
# | Trial name            | status   | loc   | hidden_sizes         |   learning_rate |
# |-----------------------+----------+-------+----------------------+-----------------|
# | train_ann_82f07_00004 | PENDING  |       | [128, 64, 32, 1_5a80 |          0.0001 |
# | train_ann_82f07_00005 | PENDING  |       | [128, 64, 32, 1_df80 |          1e-05  |
# | train_ann_82f07_00006 | PENDING  |       | [128, 64, 32, 1_f980 |          0.001  |
# | train_ann_82f07_00007 | PENDING  |       | [128, 64, 32, 16]    |          0.0001 |
# | train_ann_82f07_00008 | PENDING  |       | [128, 64, 32, 16]    |          1e-05  |
# | train_ann_82f07_00009 | PENDING  |       | [128, 64, 32, 1_5140 |          0.001  |
# | train_ann_82f07_00010 | PENDING  |       | [128, 64, 32, 1_e940 |          0.0001 |
# | train_ann_82f07_00011 | PENDING  |       | [128, 64, 32, 1_6340 |          1e-05  |
# | train_ann_82f07_00012 | PENDING  |       | [128, 64, 32, 1_6940 |          0.001  |
# | train_ann_82f07_00013 | PENDING  |       | [128, 64, 32, 1_5400 |          0.0001 |
# | train_ann_82f07_00014 | PENDING  |       | [128, 64, 32, 1_f140 |          1e-05  |
# | train_ann_82f07_00015 | PENDING  |       | [128, 64, 32, 1_cb80 |          0.001  |
# | train_ann_82f07_00016 | PENDING  |       | [128, 64, 32, 1_ff40 |          0.0001 |
# | train_ann_82f07_00017 | PENDING  |       | [128, 64, 32, 1_4040 |          1e-05  |
# | train_ann_82f07_00018 | PENDING  |       | [128, 64, 32, 1_e1c0 |          0.001  |
# | train_ann_82f07_00019 | PENDING  |       | [128, 64, 32, 1_d900 |          0.0001 |
# | train_ann_82f07_00000 | ERROR    |       | [128, 64, 32, 1_4540 |          0.001  |
# | train_ann_82f07_00001 | ERROR    |       | [128, 64, 32, 1_f200 |          0.0001 |
# | train_ann_82f07_00002 | ERROR    |       | [128, 64, 32, 1_4cc0 |          1e-05  |
# | train_ann_82f07_00003 | ERROR    |       | [128, 64, 32, 1_f180 |          0.001  |
# +-----------------------+----------+-------+----------------------+-----------------+
# Number of errored trials: 4
# +-----------------------+--------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name            |   # failures | error file                                                                                                                                                                                                            |
# |-----------------------+--------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | train_ann_82f07_00000 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00000_0_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0010_2023-11-21_17-58-40/error.txt                                   |
# | train_ann_82f07_00001 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00001_1_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_12_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00002 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00002_2_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0000_2023-11-21_17-58-40/error.txt                                   |
# | train_ann_82f07_00003 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00003_3_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0010_2023-11-21_17-58-40/error.txt                                   |
# +-----------------------+--------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# 2023-11-21 17:58:55,362	WARNING worker.py:2074 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1669, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1769, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1675, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1615, in ray._raylet.execute_task.function_executor
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# ...
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 2064, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1960, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 1617, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1618, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 1856, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 918, in ray._raylet.store_task_errors
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 638, in temporary_actor_method
#     raise RuntimeError(
# RuntimeError: The actor with name ImplicitFunc failed to import on the worker. This may be because needed library dependencies are not installed in the worker environment:
#
# Traceback (most recent call last):
#   File "/home/will/.local/lib/python3.10/site-packages/ray/_private/function_manager.py", line 677, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
# ModuleNotFoundError: No module named 'hyperparameter_tuner'
#
# An unexpected internal error occurred while the worker was executing a task.
# == Status ==
# Current time: 2023-11-21 17:59:39 (running for 00:00:59.75)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None
# Logical resource usage: 0/4 CPUs, 0/0 GPUs
# Result logdir: /home/will/ray_results/train_ann_2023-11-21_17-58-40
# Number of trials: 30/30 (30 ERROR)
# +-----------------------+----------+-------+----------------------+-----------------+
# | Trial name            | status   | loc   | hidden_sizes         |   learning_rate |
# |-----------------------+----------+-------+----------------------+-----------------|
# | train_ann_82f07_00000 | ERROR    |       | [128, 64, 32, 1_4540 |          0.001  |
# | train_ann_82f07_00001 | ERROR    |       | [128, 64, 32, 1_f200 |          0.0001 |
# | train_ann_82f07_00002 | ERROR    |       | [128, 64, 32, 1_4cc0 |          1e-05  |
# | train_ann_82f07_00003 | ERROR    |       | [128, 64, 32, 1_f180 |          0.001  |
# | train_ann_82f07_00004 | ERROR    |       | [128, 64, 32, 1_5a80 |          0.0001 |
# | train_ann_82f07_00005 | ERROR    |       | [128, 64, 32, 1_df80 |          1e-05  |
# | train_ann_82f07_00006 | ERROR    |       | [128, 64, 32, 1_f980 |          0.001  |
# | train_ann_82f07_00007 | ERROR    |       | [128, 64, 32, 16]    |          0.0001 |
# | train_ann_82f07_00008 | ERROR    |       | [128, 64, 32, 16]    |          1e-05  |
# | train_ann_82f07_00009 | ERROR    |       | [128, 64, 32, 1_5140 |          0.001  |
# | train_ann_82f07_00010 | ERROR    |       | [128, 64, 32, 1_e940 |          0.0001 |
# | train_ann_82f07_00011 | ERROR    |       | [128, 64, 32, 1_6340 |          1e-05  |
# | train_ann_82f07_00012 | ERROR    |       | [128, 64, 32, 1_6940 |          0.001  |
# | train_ann_82f07_00013 | ERROR    |       | [128, 64, 32, 1_5400 |          0.0001 |
# | train_ann_82f07_00014 | ERROR    |       | [128, 64, 32, 1_f140 |          1e-05  |
# | train_ann_82f07_00015 | ERROR    |       | [128, 64, 32, 1_cb80 |          0.001  |
# | train_ann_82f07_00016 | ERROR    |       | [128, 64, 32, 1_ff40 |          0.0001 |
# | train_ann_82f07_00017 | ERROR    |       | [128, 64, 32, 1_4040 |          1e-05  |
# | train_ann_82f07_00018 | ERROR    |       | [128, 64, 32, 1_e1c0 |          0.001  |
# | train_ann_82f07_00019 | ERROR    |       | [128, 64, 32, 1_d900 |          0.0001 |
# | train_ann_82f07_00020 | ERROR    |       | [128, 64, 32, 1_7980 |          1e-05  |
# | train_ann_82f07_00021 | ERROR    |       | [128, 64, 32, 1_66c0 |          0.001  |
# | train_ann_82f07_00022 | ERROR    |       | [128, 64, 32, 1_6900 |          0.0001 |
# | train_ann_82f07_00023 | ERROR    |       | [128, 64, 32, 1_68c0 |          1e-05  |
# | train_ann_82f07_00024 | ERROR    |       | [128, 64, 32, 1_ec00 |          0.001  |
# | train_ann_82f07_00025 | ERROR    |       | [128, 64, 32, 1_c800 |          0.0001 |
# | train_ann_82f07_00026 | ERROR    |       | [128, 64, 32, 1_da00 |          1e-05  |
# | train_ann_82f07_00027 | ERROR    |       | [128, 64, 32, 1_e2c0 |          0.001  |
# | train_ann_82f07_00028 | ERROR    |       | [128, 64, 32, 1_cc40 |          0.0001 |
# | train_ann_82f07_00029 | ERROR    |       | [128, 64, 32, 1_a700 |          1e-05  |
# +-----------------------+----------+-------+----------------------+-----------------+
# Number of errored trials: 30
# +-----------------------+--------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name            |   # failures | error file                                                                                                                                                                                                            |
# |-----------------------+--------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | train_ann_82f07_00000 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00000_0_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0010_2023-11-21_17-58-40/error.txt                                   |
# | train_ann_82f07_00001 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00001_1_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_12_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00002 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00002_2_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0000_2023-11-21_17-58-40/error.txt                                   |
# | train_ann_82f07_00003 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00003_3_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0010_2023-11-21_17-58-40/error.txt                                   |
# | train_ann_82f07_00004 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00004_4_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_12_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00005 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00005_5_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_12_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00006 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00006_6_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_12_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00007 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00007_7_hidden_sizes=128_64_32_16,learning_rate=0.0001_2023-11-21_17-58-40/error.txt                                                             |
# | train_ann_82f07_00008 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00008_8_hidden_sizes=128_64_32_16,learning_rate=0.0000_2023-11-21_17-58-40/error.txt                                                             |
# | train_ann_82f07_00009 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00009_9_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_12_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00010 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00010_10_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00011 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00011_11_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16,l_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00012 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00012_12_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00013 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00013_13_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00014 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00014_14_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00015 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00015_15_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-58-40/error.txt |
# | train_ann_82f07_00016 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00016_16_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0001_2023-11-21_17-58-46/error.txt                     |
# | train_ann_82f07_00017 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00017_17_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0000_2023-11-21_17-58-46/error.txt                     |
# | train_ann_82f07_00018 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00018_18_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-58-46/error.txt |
# | train_ann_82f07_00019 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00019_19_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0001_2023-11-21_17-58-46/error.txt                                  |
# | train_ann_82f07_00020 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00020_20_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-58-55/error.txt |
# | train_ann_82f07_00021 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00021_21_hidden_sizes=128_64_32_16_128_64_32_16,learning_rate=0.0010_2023-11-21_17-58-55/error.txt                                               |
# | train_ann_82f07_00022 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00022_22_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-58-55/error.txt |
# | train_ann_82f07_00023 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00023_23_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-58-57/error.txt |
# | train_ann_82f07_00024 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00024_24_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0010_2023-11-21_17-59-04/error.txt                                  |
# | train_ann_82f07_00025 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00025_25_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-59-04/error.txt |
# | train_ann_82f07_00026 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00026_26_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_1_2023-11-21_17-59-04/error.txt |
# | train_ann_82f07_00027 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00027_27_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=_2023-11-21_17-59-06/error.txt |
# | train_ann_82f07_00028 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00028_28_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=0.0001_2023-11-21_17-59-11/error.txt                     |
# | train_ann_82f07_00029 |            1 | /home/will/ray_results/train_ann_2023-11-21_17-58-40/train_ann_82f07_00029_29_hidden_sizes=128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16_128_64_32_16,learning_rate=_2023-11-21_17-59-11/error.txt |
# +-----------------------+--------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 tuner = HyperparameterTuner()
# ----> 2 tuner.tune_ann()
#
# File ~/School/PFE/PFE-A2023-Classification-Modulation/src/neural_network/hyperparameter_tuner.py:52, in HyperparameterTuner.tune_ann(self)
#      49 reporter = CLIReporter(metric_columns=["loss", "accuracy", "training_iteration"])
#      50 scheduler = ASHAScheduler(metric="loss", mode="min")
# ---> 52 analysis = tune.run(
#      53     self.train_ann,
#      54     resources_per_trial={"cpu": 1},  # Ajustez selon vos ressources disponibles
#      55     config=config,
#      56     num_samples=10,
#      57     scheduler=scheduler,
#      58     progress_reporter=reporter
#      59 )
#      61 best_trial = analysis.get_best_trial("loss", "min", "last")
#      62 print("Meilleurs hyperparamètres trouvés étaient: ", best_trial.config)
#
# File ~/.local/lib/python3.10/site-packages/ray/tune/tune.py:1041, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _experiment_checkpoint_dir, _remote, _remote_string_queue, _entrypoint)
#    1039 if incomplete_trials:
#    1040     if raise_on_failed_trial and not experiment_interrupted_event.is_set():
# -> 1041         raise TuneError("Trials did not complete", incomplete_trials)
#    1042     else:
#    1043         logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [train_ann_82f07_00000, train_ann_82f07_00001, train_ann_82f07_00002, train_ann_82f07_00003, train_ann_82f07_00004, train_ann_82f07_00005, train_ann_82f07_00006, train_ann_82f07_00007, train_ann_82f07_00008, train_ann_82f07_00009, train_ann_82f07_00010, train_ann_82f07_00011, train_ann_82f07_00012, train_ann_82f07_00013, train_ann_82f07_00014, train_ann_82f07_00015, train_ann_82f07_00016, train_ann_82f07_00017, train_ann_82f07_00018, train_ann_82f07_00019, train_ann_82f07_00020, train_ann_82f07_00021, train_ann_82f07_00022, train_ann_82f07_00023, train_ann_82f07_00024, train_ann_82f07_00025, train_ann_82f07_00026, train_ann_82f07_00027, train_ann_82f07_00028, train_ann_82f07_00029])
