# %%
import sys
import os
import matplotlib.pyplot as plt
sys.path.append("neural_network")
from trainer import Trainer
from nn_model import NNModel
from ann_model import ANNModel
from cnn_model import CNNModel
from t_cnn_model import TCNModel
from hyperparameter_manager import HyperparameterManager
from waveform_batch_manager import WaveformBatchManager
import nn_transforms

import datetime

param_manager = HyperparameterManager()

# %% [markdown]
# # ANN

# %%
parameters_ANN = param_manager.get_ann_parameters()
data_dir = ['../data/raw/QPSK_1', '../data/raw/PAM_VF', '../data/raw/PWM_VF'] 
train_set = WaveformBatchManager(data_dir,  128)

trainer_ann = Trainer(ANNModel, parameters_ANN, train_set=train_set, batch_size_=32, num_workers_=2)
# Out:
# Adding SNR value: 14
# Adding SNR value: 3
# Adding SNR value: 5
# Adding SNR value: 15
# Adding SNR value: 19
# Adding SNR value: 13
# Adding SNR value: 2
# Adding SNR value: 17
# Adding SNR value: 8
# Adding SNR value: 7
# Adding SNR value: 10
# Adding SNR value: 18
# Adding SNR value: 6
# Adding SNR value: 11
# Adding SNR value: 9
# Adding SNR value: 12
# Adding SNR value: 16
# Adding SNR value: 20
# Adding SNR value: 1
# Adding SNR value: 4
#
#
# Lenght file list : 60000

# %% [markdown]
# ## Train

# %%
loss_per_epoch = trainer_ann.train(20)
# Out:
# 54000
# [1,  1000] loss: 0.218
# Epoch 1 completed in 58.33 seconds
# Loss=0.1630333905768259; Accuracy=93.22947540011856
# [2,  1000] loss: 0.022
# Epoch 2 completed in 71.31 seconds
# Loss=0.025637417296501628; Accuracy=99.1275192649674
# [3,  1000] loss: 0.019
# Epoch 3 completed in 54.73 seconds
# Loss=0.01960192393326223; Accuracy=99.3572169531713
# [4,  1000] loss: 0.013
# Epoch 4 completed in 54.23 seconds
# Loss=0.012587009136089681; Accuracy=99.57024303497333
# [5,  1000] loss: 0.045
# Epoch 5 completed in 53.64 seconds
# Loss=0.032789415705648424; Accuracy=99.12381446354475
# [6,  1000] loss: 0.017
# Epoch 6 completed in 53.23 seconds
# Loss=0.014531629039702692; Accuracy=99.55357142857143
# [7,  1000] loss: 0.008
# Early stopping triggered after 7 epochs
# Finished Training in 400.51696467 seconds

# %%
# export loss to csv
import numpy as np
import pandas as pd
loss_per_epoch_np = np.array(loss_per_epoch)

DF = pd.DataFrame(loss_per_epoch_np)
DF.to_csv("data1.csv")

# %% [markdown]
# # Eval

# %%
snrs= range(1, 21, 1)
accuracy_ann = []
for snr in snrs:
    total_accuracy = 0
    nb_it = 20
    for i in range(nb_it):
        total_accuracy += trainer_ann.eval_by_snr(snr)
    average_accuracy = total_accuracy/nb_it
    accuracy_ann.append(average_accuracy)

print(accuracy_ann)
# Out:
# 18
# Finished evaluation in 2.74594402 seconds
# 18
# Finished evaluation in 2.57982826 seconds
# 18
# Finished evaluation in 2.58541226 seconds
# 18
# Finished evaluation in 3.16878557 seconds
# 18
# Finished evaluation in 2.67027545 seconds
# 18
# Finished evaluation in 2.70045781 seconds
# 18
# Finished evaluation in 2.72944379 seconds
# 18
# Finished evaluation in 2.69750285 seconds
# 18
# Finished evaluation in 2.63719606 seconds
# 18
# Finished evaluation in 2.56975317 seconds
# 18
# Finished evaluation in 3.03813362 seconds
# 18
# Finished evaluation in 3.45800090 seconds
# 18
# Finished evaluation in 2.74953580 seconds
# 18
# Finished evaluation in 2.80609369 seconds
# 18
# Finished evaluation in 2.54173446 seconds
# 18
# Finished evaluation in 2.60034657 seconds
# 18
# Finished evaluation in 2.81925488 seconds
# 18
# Finished evaluation in 2.95495629 seconds
# 18
# Finished evaluation in 2.62822413 seconds
# 18
# Finished evaluation in 2.86647224 seconds
# 6
# Finished evaluation in 2.66020465 seconds
# 6
# Finished evaluation in 2.66312289 seconds
# 6
# Finished evaluation in 2.64541054 seconds
# 6
# Finished evaluation in 2.83150148 seconds
# 6
# Finished evaluation in 2.76436138 seconds
# 6
# Finished evaluation in 2.72415829 seconds
# 6
# Finished evaluation in 2.73708415 seconds
# 6
# Finished evaluation in 2.85155368 seconds
# 6
# Finished evaluation in 2.72935629 seconds
# 6
# Finished evaluation in 3.40124273 seconds
# 6
# Finished evaluation in 2.90098906 seconds
# 6
# Finished evaluation in 3.50387239 seconds
# 6
# Finished evaluation in 2.89993143 seconds
# 6
# Finished evaluation in 2.83183432 seconds
# 6
# Finished evaluation in 2.94451213 seconds
# 6
# Finished evaluation in 2.86735606 seconds
# 6
# Finished evaluation in 2.79741812 seconds
# 6
# Finished evaluation in 2.96482635 seconds
# 6
# Finished evaluation in 2.61266541 seconds
# 6
# Finished evaluation in 2.58394694 seconds
# 1
# Finished evaluation in 2.59790564 seconds
# 1
# Finished evaluation in 2.56712127 seconds
# 1
# Finished evaluation in 2.56062150 seconds
# 1
# Finished evaluation in 2.58334780 seconds
# 1
# Finished evaluation in 2.58174372 seconds
# 1
# Finished evaluation in 2.57280993 seconds
# 1
# Finished evaluation in 2.75365663 seconds
# 1
# Finished evaluation in 2.61110926 seconds
# 1
# Finished evaluation in 2.77441788 seconds
# 1
# Finished evaluation in 2.86227751 seconds
# 1
# Finished evaluation in 3.41392398 seconds
# 1
# Finished evaluation in 2.71356463 seconds
# 1
# Finished evaluation in 3.21564460 seconds
# 1
# Finished evaluation in 3.13993502 seconds
# 1
# Finished evaluation in 3.06946945 seconds
# 1
# Finished evaluation in 3.11596346 seconds
# 1
# Finished evaluation in 2.87667823 seconds
# 1
# Finished evaluation in 3.75601244 seconds
# 1
# Finished evaluation in 5.08674765 seconds
# 1
# Finished evaluation in 4.21941447 seconds
# 19
# Finished evaluation in 3.06286073 seconds
# 19
# Finished evaluation in 3.21131587 seconds
# 19
# Finished evaluation in 2.95004702 seconds
# 19
# Finished evaluation in 2.84932971 seconds
# 19
# Finished evaluation in 3.21991277 seconds
# 19
# Finished evaluation in 2.95150328 seconds
# 19
# Finished evaluation in 2.93414712 seconds
# 19
# Finished evaluation in 3.03804755 seconds
# 19
# Finished evaluation in 2.79416156 seconds
# 19
# Finished evaluation in 2.77044463 seconds
# 19
# Finished evaluation in 2.75854301 seconds
# 19
# Finished evaluation in 2.76142550 seconds
# 19
# Finished evaluation in 3.26631355 seconds
# 19
# Finished evaluation in 2.97829962 seconds
# 19
# Finished evaluation in 2.83606172 seconds
# 19
# Finished evaluation in 3.00050211 seconds
# 19
# Finished evaluation in 3.23640466 seconds
# 19
# Finished evaluation in 3.25122237 seconds
# 19
# Finished evaluation in 3.06355262 seconds
# 19
# Finished evaluation in 3.16544485 seconds
# 2
# Finished evaluation in 3.07778358 seconds
# 2
# Finished evaluation in 2.93789506 seconds
# 2
# Finished evaluation in 3.04042292 seconds
# 2
# Finished evaluation in 3.02731347 seconds
# 2
# Finished evaluation in 2.82780027 seconds
# 2
# Finished evaluation in 3.51739740 seconds
# 2
# Finished evaluation in 3.02734494 seconds
# 2
# Finished evaluation in 3.23396873 seconds
# 2
# Finished evaluation in 2.95308757 seconds
# 2
# Finished evaluation in 3.49681640 seconds
# 2
# Finished evaluation in 2.85908198 seconds
# 2
# Finished evaluation in 3.02775335 seconds
# 2
# Finished evaluation in 2.82708955 seconds
# 2
# Finished evaluation in 2.83792472 seconds
# 2
# Finished evaluation in 2.99435186 seconds
# 2
# Finished evaluation in 3.24667239 seconds
# 2
# Finished evaluation in 2.82290292 seconds
# 2
# Finished evaluation in 3.07374668 seconds
# 2
# Finished evaluation in 3.46059728 seconds
# 2
# Finished evaluation in 3.39134574 seconds
# 12
# Finished evaluation in 2.92865205 seconds
# 12
# Finished evaluation in 3.00990176 seconds
# 12
# Finished evaluation in 3.28353357 seconds
# 12
# Finished evaluation in 3.37258005 seconds
# 12
# Finished evaluation in 3.32490253 seconds
# 12
# Finished evaluation in 3.22770166 seconds
# 12
# Finished evaluation in 2.94641685 seconds
# 12
# Finished evaluation in 3.26972151 seconds
# 12
# Finished evaluation in 3.02706003 seconds
# 12
# Finished evaluation in 2.96472549 seconds
# 12
# Finished evaluation in 2.83216071 seconds
# 12
# Finished evaluation in 3.03136826 seconds
# 12
# Finished evaluation in 2.92806292 seconds
# 12
# Finished evaluation in 3.01153755 seconds
# 12
# Finished evaluation in 2.87680531 seconds
# 12
# Finished evaluation in 3.32609463 seconds
# 12
# Finished evaluation in 2.91695666 seconds
# 12
# Finished evaluation in 3.19455743 seconds
# 12
# Finished evaluation in 3.08913183 seconds
# 12
# Finished evaluation in 3.45361948 seconds
# 9
# Finished evaluation in 3.52484059 seconds
# 9
# Finished evaluation in 3.23498559 seconds
# 9
# Finished evaluation in 3.21365619 seconds
# 9
# Finished evaluation in 3.23226166 seconds
# 9
# Finished evaluation in 3.01249218 seconds
# 9
# Finished evaluation in 2.92362642 seconds
# 9
# Finished evaluation in 2.96936846 seconds
# 9
# Finished evaluation in 2.97822618 seconds
# 9
# Finished evaluation in 3.08842635 seconds
# 9
# Finished evaluation in 3.32517672 seconds
# 9
# Finished evaluation in 3.06622028 seconds
# 9
# Finished evaluation in 4.17340899 seconds
# 9
# Finished evaluation in 2.87663269 seconds
# 9
# Finished evaluation in 2.87808013 seconds
# 9
# Finished evaluation in 3.21124625 seconds
# 9
# Finished evaluation in 2.79209685 seconds
# 9
# Finished evaluation in 2.78898120 seconds
# 9
# Finished evaluation in 3.08552146 seconds
# 9
# Finished evaluation in 3.43290687 seconds
# 9
# Finished evaluation in 3.01105380 seconds
# 8
# Finished evaluation in 3.38127542 seconds
# 8
# Finished evaluation in 3.10217738 seconds
# 8
# Finished evaluation in 2.84390426 seconds
# 8
# Finished evaluation in 2.96640229 seconds
# 8
# Finished evaluation in 3.13787198 seconds
# 8
# Finished evaluation in 2.83440900 seconds
# 8
# Finished evaluation in 2.83817482 seconds
# 8
# Finished evaluation in 3.09050822 seconds
# 8
# Finished evaluation in 3.13624835 seconds
# 8
# Finished evaluation in 3.77970219 seconds
# 8
# Finished evaluation in 3.16678023 seconds
# 8
# Finished evaluation in 2.97048259 seconds
# 8
# Finished evaluation in 2.83120537 seconds
# 8
# Finished evaluation in 3.05151010 seconds
# 8
# Finished evaluation in 3.25402737 seconds
# 8
# Finished evaluation in 3.29593277 seconds
# 8
# Finished evaluation in 3.22560072 seconds
# 8
# Finished evaluation in 2.82553554 seconds
# 8
# Finished evaluation in 3.50397396 seconds
# 8
# Finished evaluation in 3.12509298 seconds
# 14
# Finished evaluation in 2.88055110 seconds
# 14
# Finished evaluation in 2.82371330 seconds
# 14
# Finished evaluation in 2.94439530 seconds
# 14
# Finished evaluation in 2.91988015 seconds
# 14
# Finished evaluation in 2.78477097 seconds
# 14
# Finished evaluation in 2.66135931 seconds
# 14
# Finished evaluation in 3.47559857 seconds
# 14
# Finished evaluation in 3.11949229 seconds
# 14
# Finished evaluation in 2.85774469 seconds
# 14
# Finished evaluation in 2.62405419 seconds
# 14
# Finished evaluation in 4.35961151 seconds
# 14
# Finished evaluation in 2.86419773 seconds
# 14
# Finished evaluation in 2.83782077 seconds
# 14
# Finished evaluation in 3.21750379 seconds
# 14
# Finished evaluation in 3.12207818 seconds
# 14
# Finished evaluation in 3.17396045 seconds
# 14
# Finished evaluation in 3.04620481 seconds
# 14
# Finished evaluation in 2.85684633 seconds
# 14
# Finished evaluation in 2.70252776 seconds
# 14
# Finished evaluation in 2.87018800 seconds
# 10
# Finished evaluation in 3.03788662 seconds
# 10
# Finished evaluation in 3.22577333 seconds
# 10
# Finished evaluation in 2.70515871 seconds
# 10
# Finished evaluation in 3.21002054 seconds
# 10
# Finished evaluation in 2.71027446 seconds
# 10
# Finished evaluation in 3.01174927 seconds
# 10
# Finished evaluation in 2.68466640 seconds
# 10
# Finished evaluation in 2.63644695 seconds
# 10
# Finished evaluation in 2.60598493 seconds
# 10
# Finished evaluation in 3.01538563 seconds
# 10
# Finished evaluation in 2.59492564 seconds
# 10
# Finished evaluation in 2.63801050 seconds
# 10
# Finished evaluation in 2.60159063 seconds
# 10
# Finished evaluation in 2.63031268 seconds
# 10
# Finished evaluation in 2.60933399 seconds
# 10
# Finished evaluation in 2.65858555 seconds
# 10
# Finished evaluation in 2.68236136 seconds
# 10
# Finished evaluation in 2.70213699 seconds
# 10
# Finished evaluation in 2.75424027 seconds
# 10
# Finished evaluation in 2.65776730 seconds
# 13
# Finished evaluation in 2.64239573 seconds
# 13
# Finished evaluation in 2.63514209 seconds
# 13
# Finished evaluation in 2.61618590 seconds
# 13
# Finished evaluation in 2.76017547 seconds
# 13
# Finished evaluation in 3.11735511 seconds
# 13
# Finished evaluation in 2.60078788 seconds
# 13
# Finished evaluation in 2.68558884 seconds
# 13
# Finished evaluation in 2.62345886 seconds
# 13
# Finished evaluation in 2.63423657 seconds
# 13
# Finished evaluation in 2.61263943 seconds
# 13
# Finished evaluation in 2.63682222 seconds
# 13
# Finished evaluation in 2.61135101 seconds
# 13
# Finished evaluation in 2.63167405 seconds
# 13
# Finished evaluation in 2.59020638 seconds
# 13
# Finished evaluation in 2.62706280 seconds
# 13
# Finished evaluation in 2.85238433 seconds
# 13
# Finished evaluation in 3.32792568 seconds
# 13
# Finished evaluation in 2.63658977 seconds
# 13
# Finished evaluation in 2.63554335 seconds
# 13
# Finished evaluation in 2.69658351 seconds
# 15
# Finished evaluation in 2.62447000 seconds
# 15
# Finished evaluation in 2.65235925 seconds
# 15
# Finished evaluation in 2.60248089 seconds
# 15
# Finished evaluation in 2.60889506 seconds
# 15
# Finished evaluation in 2.63671589 seconds
# 15
# Finished evaluation in 2.68198013 seconds
# 15
# Finished evaluation in 2.64169359 seconds
# 15
# Finished evaluation in 2.63051462 seconds
# 15
# Finished evaluation in 2.68732476 seconds
# 15
# Finished evaluation in 2.79392695 seconds
# 15
# Finished evaluation in 2.67636681 seconds
# 15
# Finished evaluation in 2.65367413 seconds
# 15
# Finished evaluation in 2.79065847 seconds
# 15
# Finished evaluation in 2.78588057 seconds
# 15
# Finished evaluation in 3.17901039 seconds
# 15
# Finished evaluation in 3.65886712 seconds
# 15
# Finished evaluation in 3.32943225 seconds
# 15
# Finished evaluation in 2.68719888 seconds
# 15
# Finished evaluation in 2.81694317 seconds
# 15
# Finished evaluation in 2.75457120 seconds
# 5
# Finished evaluation in 2.58833218 seconds
# 5
# Finished evaluation in 2.65136051 seconds
# 5
# Finished evaluation in 2.66303611 seconds
# 5
# Finished evaluation in 2.97965527 seconds
# 5
# Finished evaluation in 2.74880981 seconds
# 5
# Finished evaluation in 2.61080003 seconds
# 5
# Finished evaluation in 2.63569403 seconds
# 5
# Finished evaluation in 2.73653388 seconds
# 5
# Finished evaluation in 2.67120624 seconds
# 5
# Finished evaluation in 2.68929005 seconds
# 5
# Finished evaluation in 2.60737824 seconds
# 5
# Finished evaluation in 2.64342213 seconds
# 5
# Finished evaluation in 2.63474679 seconds
# 5
# Finished evaluation in 2.64471865 seconds
# 5
# Finished evaluation in 2.62593055 seconds
# 5
# Finished evaluation in 2.68745828 seconds
# 5
# Finished evaluation in 2.69480133 seconds
# 5
# Finished evaluation in 2.60676217 seconds
# 5
# Finished evaluation in 2.63953733 seconds
# 5
# Finished evaluation in 2.66561341 seconds
# 0
# Finished evaluation in 2.66969466 seconds
# 0
# Finished evaluation in 2.62242627 seconds
# 0
# Finished evaluation in 2.62787700 seconds
# 0
# Finished evaluation in 2.68876600 seconds
# 0
# Finished evaluation in 2.56933165 seconds
# 0
# Finished evaluation in 2.72450137 seconds
# 0
# Finished evaluation in 2.60948920 seconds
# 0
# Finished evaluation in 2.63241076 seconds
# 0
# Finished evaluation in 2.63731837 seconds
# 0
# Finished evaluation in 2.61217022 seconds
# 0
# Finished evaluation in 2.63044524 seconds
# 0
# Finished evaluation in 2.67726970 seconds
# 0
# Finished evaluation in 2.72017932 seconds
# 0
# Finished evaluation in 2.67846370 seconds
# 0
# Finished evaluation in 3.28637528 seconds
# 0
# Finished evaluation in 2.69920540 seconds
# 0
# Finished evaluation in 2.64367151 seconds
# 0
# Finished evaluation in 2.83121371 seconds
# 0
# Finished evaluation in 2.77733898 seconds
# 0
# Finished evaluation in 2.63443136 seconds
# 3
# Finished evaluation in 2.63297129 seconds
# 3
# Finished evaluation in 2.66649127 seconds
# 3
# Finished evaluation in 2.65868139 seconds
# 3
# Finished evaluation in 2.61358762 seconds
# 3
# Finished evaluation in 2.65621042 seconds
# 3
# Finished evaluation in 2.62358022 seconds
# 3
# Finished evaluation in 2.58867502 seconds
# 3
# Finished evaluation in 2.64350533 seconds
# 3
# Finished evaluation in 2.61848044 seconds
# 3
# Finished evaluation in 2.62764645 seconds
# 3
# Finished evaluation in 3.08770919 seconds
# 3
# Finished evaluation in 2.78324842 seconds
# 3
# Finished evaluation in 2.78171420 seconds
# 3
# Finished evaluation in 2.65391612 seconds
# 3
# Finished evaluation in 3.05177402 seconds
# 3
# Finished evaluation in 2.71119404 seconds
# 3
# Finished evaluation in 2.65726185 seconds
# 3
# Finished evaluation in 2.68455577 seconds
# 3
# Finished evaluation in 2.66208601 seconds
# 3
# Finished evaluation in 2.58850169 seconds
# 16
# Finished evaluation in 3.98994637 seconds
# 16
# Finished evaluation in 2.81188869 seconds
# 16
# Finished evaluation in 2.77538276 seconds
# 16
# Finished evaluation in 2.84087396 seconds
# 16
# Finished evaluation in 2.62391877 seconds
# 16
# Finished evaluation in 2.66516256 seconds
# 16
# Finished evaluation in 2.63354731 seconds
# 16
# Finished evaluation in 2.79572177 seconds
# 16
# Finished evaluation in 2.75751328 seconds
# 16
# Finished evaluation in 2.91940594 seconds
# 16
# Finished evaluation in 2.62410355 seconds
# 16
# Finished evaluation in 2.60588837 seconds
# 16
# Finished evaluation in 2.56439161 seconds
# 16
# Finished evaluation in 2.59728193 seconds
# 16
# Finished evaluation in 2.58940744 seconds
# 16
# Finished evaluation in 2.54224968 seconds
# 16
# Finished evaluation in 2.56221581 seconds
# 16
# Finished evaluation in 2.57705760 seconds
# 16
# Finished evaluation in 2.57532525 seconds
# 16
# Finished evaluation in 2.56348205 seconds
# 7
# Finished evaluation in 2.58071756 seconds
# 7
# Finished evaluation in 2.68140674 seconds
# 7
# Finished evaluation in 2.80720139 seconds
# 7
# Finished evaluation in 2.59850097 seconds
# 7
# Finished evaluation in 2.57137322 seconds
# 7
# Finished evaluation in 2.57590747 seconds
# 7
# Finished evaluation in 2.57440734 seconds
# 7
# Finished evaluation in 2.57068849 seconds
# 7
# Finished evaluation in 2.55162644 seconds
# 7
# Finished evaluation in 2.58565807 seconds
# 7
# Finished evaluation in 2.61974144 seconds
# 7
# Finished evaluation in 2.57468176 seconds
# 7
# Finished evaluation in 2.57659912 seconds
# 7
# Finished evaluation in 2.59180832 seconds
# 7
# Finished evaluation in 2.59243870 seconds
# 7
# Finished evaluation in 2.52963352 seconds
# 7
# Finished evaluation in 2.62277818 seconds
# 7
# Finished evaluation in 2.79916096 seconds
# 7
# Finished evaluation in 2.53064990 seconds
# 7
# Finished evaluation in 2.54393601 seconds
# 11
# Finished evaluation in 2.58655763 seconds
# 11
# Finished evaluation in 2.55676007 seconds
# 11
# Finished evaluation in 2.59044242 seconds
# 11
# Finished evaluation in 2.52849126 seconds
# 11
# Finished evaluation in 2.54726171 seconds
# 11
# Finished evaluation in 2.63751507 seconds
# 11
# Finished evaluation in 2.55561471 seconds
# 11
# Finished evaluation in 2.56130958 seconds
# 11
# Finished evaluation in 2.54692197 seconds
# 11
# Finished evaluation in 2.54509616 seconds
# 11
# Finished evaluation in 2.62882400 seconds
# 11
# Finished evaluation in 2.55467582 seconds
# 11
# Finished evaluation in 2.58896255 seconds
# 11
# Finished evaluation in 2.74306154 seconds
# 11
# Finished evaluation in 2.54109597 seconds
# 11
# Finished evaluation in 2.55835986 seconds
# 11
# Finished evaluation in 2.60030341 seconds
# 11
# Finished evaluation in 2.59315395 seconds
# 11
# Finished evaluation in 2.56079268 seconds
# 11
# Finished evaluation in 2.56120992 seconds
# 4
# Finished evaluation in 2.56244588 seconds
# 4
# Finished evaluation in 2.59695148 seconds
# 4
# Finished evaluation in 2.59107995 seconds
# 4
# Finished evaluation in 2.67289424 seconds
# 4
# Finished evaluation in 2.53828096 seconds
# 4
# Finished evaluation in 2.61988306 seconds
# 4
# Finished evaluation in 2.59850478 seconds
# 4
# Finished evaluation in 2.57485247 seconds
# 4
# Finished evaluation in 2.93148375 seconds
# 4
# Finished evaluation in 2.61918426 seconds
# 4
# Finished evaluation in 2.71871328 seconds
# 4
# Finished evaluation in 2.88393378 seconds
# 4
# Finished evaluation in 2.59474564 seconds
# 4
# Finished evaluation in 2.53502059 seconds
# 4
# Finished evaluation in 2.55726743 seconds
# 4
# Finished evaluation in 2.54936504 seconds
# 4
# Finished evaluation in 2.58364511 seconds
# 4
# Finished evaluation in 2.55995274 seconds
# 4
# Finished evaluation in 2.56007910 seconds
# 4
# Finished evaluation in 2.64975977 seconds
# 17
# Finished evaluation in 2.58852434 seconds
# 17
# Finished evaluation in 2.59009671 seconds
# 17
# Finished evaluation in 2.63516092 seconds
# 17
# Finished evaluation in 2.76654220 seconds
# 17
# Finished evaluation in 2.59351516 seconds
# 17
# Finished evaluation in 2.72371817 seconds
# 17
# Finished evaluation in 2.58841467 seconds
# 17
# Finished evaluation in 2.54752088 seconds
# 17
# Finished evaluation in 2.58073354 seconds
# 17
# Finished evaluation in 2.54749727 seconds
# 17
# Finished evaluation in 2.55340219 seconds
# 17
# Finished evaluation in 2.59106040 seconds
# 17
# Finished evaluation in 2.59082747 seconds
# 17
# Finished evaluation in 2.51198459 seconds
# 17
# Finished evaluation in 2.59486914 seconds
# 17
# Finished evaluation in 2.56195068 seconds
# 17
# Finished evaluation in 2.54027033 seconds
# 17
# Finished evaluation in 2.59250045 seconds
# 17
# Finished evaluation in 2.56900382 seconds
# 17
# Finished evaluation in 2.64524269 seconds
# [0.2484375, 0.29375, 0.2515625, 0.2578125, 0.2890625, 0.278125, 0.25, 0.25, 0.2453125, 0.2484375, 0.2578125, 0.2421875, 0.26875, 0.278125, 0.2578125, 0.253125, 0.2609375, 0.275, 0.29375, 0.2734375]

# %%
accuracy = np.array(accuracy_ann)
DF = pd.DataFrame(accuracy)
DF.to_csv("data1.csv")

# %% [markdown]
# ## Save model

# %%
ABS_PATH = '~/School/PFE/PFE-A2023-Classification-Modulation/data/nn/ANN'
dir_path = os.path.expanduser(ABS_PATH)
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
file_name = f'{timestamp}.pt'
full_path = os.path.join(dir_path, file_name)
print(full_path)

trainer_ann.save_model(file_name, dir_path)

# %% [markdown]
# # CNN

# %%
parameters_CNN = param_manager.get_cnn_parameters_1d(nb_filter_cnn_A=12,nb_layer_A=3, nb_filter_cnn_B=16, nb_layer_B=5, nb_filter_cnn_C=16, nb_layer_C = 7, learning_rate=0.0005)
transform = nn_transforms.get_transform_to_2d()

data_dir = ['../data/raw/QPSK_1', '../data/raw/PAM_VF', '../data/raw/PWM_VF'] 
#data_dir = ["../data/raw/PAM_1_10.23", "../data/raw/PWM_1_22.27"]
train_set = WaveformBatchManager(data_dir,  128)

trainer_cnn = Trainer(CNNModel, parameters_CNN, train_set=train_set, batch_size_=32, num_workers_=2, transform_ = transform)

# %% [markdown]
# ## Train

# %%
loss_per_epoch = trainer_cnn.train(20)

# %%
# export loss to csv
loss_per_epoch_np = np.array(loss_per_epoch)

DF = pd.DataFrame(loss_per_epoch_np)
DF.to_csv("data1.csv")

# %% [markdown]
# ## Eval

# %%
snrs= range(-2, 22, 2)
accuracy_cnn = []
for snr in snrs:
    total_accuracy = 0
    nb_it = 10
    for i in range(nb_it):
        total_accuracy += trainer_cnn.eval_by_snr(snr)
    average_accuracy = total_accuracy/nb_it
    accuracy_cnn.append(average_accuracy)

print(accuracy_cnn)

# %%
accuracy = np.array(accuracy_cnn)
DF = pd.DataFrame(accuracy)
DF.to_csv("data1.csv")

# %% [markdown]
# ## Save Model

# %%
ABS_PATH = '~/School/PFE/PFE-A2023-Classification-Modulation/data/nn/CNN'
dir_path = os.path.expanduser(ABS_PATH)
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
file_name = f'{timestamp}.pt'
full_path = os.path.join(dir_path, file_name)
print(full_path)

trainer_cnn.save_model(file_name, dir_path)

# %% [markdown]
# # TCN

# %%
num_channels = [12,12,12, 8,8,8,8]
parameters_TCNN = param_manager.get_t_cnn_parameters(in_channels=1, num_channels=num_channels, learning_rate=0.0005)
transform = nn_transforms.get_transform_t_cnn()
data_dir = ['../data/raw/QPSK_1', '../data/raw/PAM_VF', '../data/raw/PWM_VF'] 
#data_dir = ["../data/raw/PAM_1_10.23", "../data/raw/PWM_1_22.27"]
train_set = WaveformBatchManager(data_dir,  128)

trainer_tcnn = Trainer(TCNModel, parameters_TCNN, train_set=train_set, batch_size_=32, num_workers_=2, transform_=transform)

# %% [markdown]
# ## Train

# %%
loss_per_epoch = trainer_tcnn.train(20)

# %%
# export loss to csv
loss_per_epoch_np = np.array(loss_per_epoch)

DF = pd.DataFrame(loss_per_epoch_np)
DF.to_csv("data1.csv")

# %% [markdown]
# ## Eval

# %%
snrs= range(-2, 22, 2)
accuracy_tcn = []
for snr in snrs:
    total_accuracy = 0
    nb_it = 10
    for i in range(nb_it):
        total_accuracy += trainer_tcnn.eval_by_snr(snr)
    average_accuracy = total_accuracy/nb_it
    accuracy_tcn.append(average_accuracy)

print(accuracy_tcn)

# %%
accuracy = np.array(accuracy_tcn)
DF = pd.DataFrame(accuracy)
DF.to_csv("data1.csv")

# %% [markdown]
# ## Save

# %%
ABS_PATH = '~/School/PFE/PFE-A2023-Classification-Modulation/data/nn/TCN'
dir_path = os.path.expanduser(ABS_PATH)
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
file_name = f'{timestamp}.pt'
full_path = os.path.join(dir_path, file_name)
print(full_path)

trainer_tcnn.save_model(file_name, dir_path)
